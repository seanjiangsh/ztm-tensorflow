# %% [markdown]
# # 04. Transfer Learning with TensorFlow Part 1: Feature Extraction
#
# We've built a bunch of convolutional neural networks from scratch and they all seem to be learning, however, there is still plenty of room for improvement.
#
# To improve our model(s), we could spend a while trying different configurations, adding more layers, changing the learning rate, adjusting the number of neurons per layer and more.
#
# However, doing this is very time consuming.
#
# Luckily, there's a technique we can use to save time.
#
# It's called **transfer learning**, in other words, taking the patterns (also called weights) another model has learned from another problem and using them for our own problem.
#
# There are two main benefits to using transfer learning:
# 1. Can leverage an existing neural network architecture proven to work on problems similar to our own.
# 2. Can leverage a working neural network architecture which has **already learned** patterns on similar data to our own. This often results in achieving great results with less custom data.
#
# What this means is, instead of hand-crafting our own neural network architectures or building them from scratch, we can utilise models which have worked for others.
#
# And instead of training our own models from scratch on our own datasets, we can take the patterns a model has learned from datasets such as [ImageNet](http://www.image-net.org/) (millions of images of different objects) and use them as the foundation of our own. Doing this often leads to getting great results with less data.
#
# Over the next few notebooks, we'll see the power of transfer learning in action.
#
# ## What we're going to cover
#
# We're going to go through the following with TensorFlow:
#
# - Introduce transfer learning (a way to beat all of our old self-built models)
# - Using a smaller dataset to experiment faster (10% of training samples of 10 classes of food)
# - Build a transfer learning feature extraction model using TensorFlow Hub
# - Introduce the TensorBoard callback to track model training results
# - Compare model results using TensorBoard

# %% [markdown]
# ## Using a GPU
#
# To begin, let's check to see if we're using a GPU. Using a GPU will make sure our model trains faster than using just a CPU.

# %%
# Are we using a GPU?
# !nvidia-smi
# Out:
# Sun Jan  5 09:02:51 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.02              Driver Version: 560.94         CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4070 ...    On  |   00000000:65:00.0 Off |                  N/A |
# | N/A   48C    P3             11W /   74W |       0MiB /   8188MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## Transfer leanring with TensorFlow Hub: Getting great results with 10% of the data
#
# If you've been thinking, "surely someone else has spent the time crafting the right model for the job..." then you're in luck.
#
# For many of the problems you'll want to use deep learning for, chances are, a working model already exists.
#
# And the good news is, you can access many of them on TensorFlow Hub.
#
# [TensorFlow Hub](https://tfhub.dev/) is a repository for existing model components. It makes it so you can import and use a fully trained model with as little as a URL.
#
# Now, I really want to demonstrate the power of transfer learning to you.
#
# To do so, what if I told you we could get much of the same results (or better) than our best model has gotten so far with only 10% of the original data, in other words, 10x less data.
#
# This seems counterintuitive right?
#
# Wouldn't you think more examples of what a picture of food looked like led to better results?
#
# And you'd be right if you thought so, generally, more data leads to better results.
#
# However, what if you didn't have more data? What if instead of 750 images per class, you had 75 images per class?
#
# Collecting 675 more images of a certain class could take a long time.
#
# So this is where another major benefit of transfer learning comes in.
#
# **Transfer learning often allows you to get great results with less data.**
#
# But don't just take my word for it. Let's download a subset of the data we've been using, namely 10% of the training data from the `10_food_classes` dataset and use it to train a food image classifier on.
#
# ![](https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/images/04-transfer-learning-feature-extraction.png)
# *What we're working towards building. Taking a pre-trained model and adding our own custom layers on top, extracting all of the underlying patterns learned on another dataset our own images.*

# %% [markdown]
# ## Downloading and becoming one with the data

# %%
# Download zip file of 10_food_classes_10_percent images

# Download data (Skip, load the data locally)
# !wget https://storage.googleapis.com/ztm_tf_course/food_vision/10_food_classes_10_percent.zip

# %%
# How many images in each folder?
import os

food_classes_dir = "data/image_data/10_food_classes_10_percent"
# Walk through 10 percent data directory and list number of files
for dirpath, dirnames, filenames in os.walk(food_classes_dir):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 2 directories and 0 images in 'data/image_data/10_food_classes_10_percent'.
# There are 10 directories and 0 images in 'data/image_data/10_food_classes_10_percent/test'.
# There are 0 directories and 250 images in 'data/image_data/10_food_classes_10_percent/test/chicken_curry'.
# There are 0 directories and 250 images in 'data/image_data/10_food_classes_10_percent/test/chicken_wings'.
# There are 0 directories and 250 images in 'data/image_data/10_food_classes_10_percent/test/fried_rice'.
# There are 0 directories and 250 images in 'data/image_data/10_food_classes_10_percent/test/grilled_salmon'.
# There are 0 directories and 250 images in 'data/image_data/10_food_classes_10_percent/test/hamburger'.
# There are 0 directories and 250 images in 'data/image_data/10_food_classes_10_percent/test/ice_cream'.
# There are 0 directories and 250 images in 'data/image_data/10_food_classes_10_percent/test/pizza'.
# There are 0 directories and 250 images in 'data/image_data/10_food_classes_10_percent/test/ramen'.
# There are 0 directories and 250 images in 'data/image_data/10_food_classes_10_percent/test/steak'.
# There are 0 directories and 250 images in 'data/image_data/10_food_classes_10_percent/test/sushi'.
# There are 10 directories and 0 images in 'data/image_data/10_food_classes_10_percent/train'.
# There are 0 directories and 75 images in 'data/image_data/10_food_classes_10_percent/train/chicken_curry'.
# There are 0 directories and 75 images in 'data/image_data/10_food_classes_10_percent/train/chicken_wings'.
# There are 0 directories and 75 images in 'data/image_data/10_food_classes_10_percent/train/fried_rice'.
# There are 0 directories and 75 images in 'data/image_data/10_food_classes_10_percent/train/grilled_salmon'.
# There are 0 directories and 75 images in 'data/image_data/10_food_classes_10_percent/train/hamburger'.
# There are 0 directories and 75 images in 'data/image_data/10_food_classes_10_percent/train/ice_cream'.
# There are 0 directories and 75 images in 'data/image_data/10_food_classes_10_percent/train/pizza'.
# There are 0 directories and 75 images in 'data/image_data/10_food_classes_10_percent/train/ramen'.
# There are 0 directories and 75 images in 'data/image_data/10_food_classes_10_percent/train/steak'.
# There are 0 directories and 75 images in 'data/image_data/10_food_classes_10_percent/train/sushi'.

# %% [markdown]
# Notice how each of the training directories now has 75 images rather than 750 images. This is key to demonstrating how well transfer learning can perform with less labelled images.
#
# The test directories still have the same amount of images. This means we'll be training on less data but evaluating our models on the same amount of test data.

# %% [markdown]
# ## Creating data loaders (preparing the data)
#
# Now we've downloaded the data, let's use the [`ImageDataGenerator`](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator) class along with the `flow_from_directory` method to load in our images.

# %%
# Setup data inputs
from tensorflow.keras.preprocessing.image import ImageDataGenerator

IMAGE_SHAPE = (224, 224)
BATCH_SIZE = 32

train_dir = food_classes_dir + "/train/"
test_dir = food_classes_dir + "/test/"

train_datagen = ImageDataGenerator(rescale=1/255.)
test_datagen = ImageDataGenerator(rescale=1/255.)

print("Training images:")
train_data_10_percent = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMAGE_SHAPE,
    batch_size=BATCH_SIZE,
    class_mode="categorical")

print("Testing images:")
test_data = train_datagen.flow_from_directory(
    test_dir,
    target_size=IMAGE_SHAPE,
    batch_size=BATCH_SIZE,
    class_mode="categorical")
# Out:
# 2025-01-05 09:03:00.485773: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-05 09:03:04.366764: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-05 09:03:05.828558: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-05 09:03:06.215402: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-05 09:03:08.944674: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-05 09:03:33.282571: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Training images:
# Found 750 images belonging to 10 classes.
# Testing images:
# Found 2500 images belonging to 10 classes.

# %% [markdown]
# Excellent! Loading in the data we can see we've got 750 images in the training dataset belonging to 10 classes (75 per class) and 2500 images in the test set belonging to 10 classes (250 per class).

# %% [markdown]
# ## Setting up callbacks (things to run whilst our model trains)
#
# Before we build a model, there's an important concept we're going to get familiar with because it's going to play a key role in our future model building experiments.
#
# And that concept is **callbacks**.
#
# [Callbacks](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks) are extra functionality you can add to your models to be performed during or after training. Some of the most popular callbacks include:
# * [**Experiment tracking with TensorBoard**](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/TensorBoard) - log the performance of multiple models and then view and compare these models in a visual way on [TensorBoard](https://www.tensorflow.org/tensorboard) (a dashboard for inspecting neural network parameters). Helpful to compare the results of different models on your data.
# * [**Model checkpointing**](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/ModelCheckpoint) - save your model as it trains so you can stop training if needed and come back to continue off where you left. Helpful if training takes a long time and can't be done in one sitting.
# * [**Early stopping**](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping) - leave your model training for an arbitrary amount of time and have it stop training automatically when it ceases to improve. Helpful when you've got a large dataset and don't know how long training will take.
#
# We'll explore each of these overtime but for this notebook, we'll see how the TensorBoard callback can be used.
#
# The TensorBoard callback can be accessed using [`tf.keras.callbacks.TensorBoard()`](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/TensorBoard).
#
# Its main functionality is saving a model's training performance metrics to a specified `log_dir`.
#
# By default, logs are recorded every epoch using the `update_freq='epoch'` parameter. This is a good default since tracking model performance too often can slow down model training.
#
# To track our modelling experiments using TensorBoard, let's create a function which creates a TensorBoard callback for us.
#
# > 🔑 **Note:** We create a function for creating a TensorBoard callback because as we'll see later on, each model needs its own TensorBoard callback instance (so the function will create a new one each time it's run).

# %%
# Create tensorboard callback (functionized because need to create a new one for each model)
import tf_keras as keras
import datetime

def create_tensorboard_callback(dir_name, experiment_name):
    log_dir = dir_name + "/" + experiment_name + "/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    tensorboard_callback = keras.callbacks.TensorBoard(
        log_dir=log_dir
    )
    print(f"Saving TensorBoard log files to: {log_dir}")
    return tensorboard_callback

# %% [markdown]
# Because you're likely to run multiple experiments, it's a good idea to be able to track them in some way.
#
# In our case, our function saves a model's performance logs to a directory named `[dir_name]/[experiment_name]/[current_timestamp]`, where:
# * `dir_name` is the overall logs directory
# * `experiment_name` is the particular experiment
# * `current_timestamp` is the time the experiment started based on Python's [`datetime.datetime().now()`](https://docs.python.org/3/library/datetime.html#datetime.datetime.now)
#
# > 🔑 **Note:** Depending on your use case, the above experimenting tracking naming method may work or you might require something more specific. The good news is, the TensorBoard callback makes it easy to track modelling logs as long as you specify where to track them. So you can get as creative as you like with how you name your experiments, just make sure you or your team can understand them.

# %% [markdown]
# ## Creating models using TensorFlow Hub
#
# In the past we've used TensorFlow to create our own models layer by layer from scratch.
#
# Now we're going to do a similar process, except the majority of our model's layers are going to come from [TensorFlow Hub](https://tfhub.dev/).
#
# In fact, we're going to use two models from TensorFlow Hub:
# 1. [ResNetV2](https://arxiv.org/abs/1603.05027) -  a state of the art computer vision model architecture from 2016.
# 2. [EfficientNet](https://arxiv.org/abs/1905.11946) - a state of the art computer vision architecture from 2019.
#
# State of the art means that at some point, both of these models have achieved the lowest error rate on [ImageNet (ILSVRC-2012-CLS)](http://www.image-net.org/), the gold standard of computer vision benchmarks.
#
# You might be wondering, how do you find these models on TensorFlow Hub?
#
# Here are the steps I took:
#
# 1. Go to [tfhub.dev](https://tfhub.dev/).
# 2. Choose your problem domain, e.g. "Image" (we're using food images).
# 3. Select your TF version, which in our case is TF2.
# 4. Remove all "Problem domanin" filters except for the problem you're working on.
#   * **Note:** "Image feature vector" can be used alongside almost any problem, we'll get to this soon.
# 5. The models listed are all models which could potentially be used for your problem.
#
# > 🤔 **Question:** *I see many options for image classification models, how do I know which is best?*
#
# You can see a list of state of the art models on [paperswithcode.com](https://www.paperswithcode.com), a resource for collecting the latest in deep learning paper results which have code implementations for the findings they report.
#
# Since we're working with images, our target are the [models which perform best on ImageNet](https://paperswithcode.com/sota/image-classification-on-imagenet).
#
# You'll probably find not all of the model architectures listed on paperswithcode appear on TensorFlow Hub. And this is okay, we can still use what's available.
#
# To find our models, let's narrow down our search using the Architecture tab.
#
# 6. Select the Architecture tab on TensorFlow Hub and you'll see a dropdown menu of architecture names appear.
#   * The rule of thumb here is generally, names with larger numbers means better performing models. For example, EfficientNetB4 performs better than EfficientNetB0.
#     * However, the tradeoff with larger numbers can mean they take longer to compute.
# 7. Select EfficientNetB0 and you should see [something like the following](https://tfhub.dev/s?module-type=image-classification,image-feature-vector&network-architecture=efficientnet-b0&tf-version=tf2):
# ![](https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/images/04-tensorflow-hub-efficientnetb0.png)
# 8. Clicking the one titled "[efficientnet/b0/feature-vector](https://tfhub.dev/tensorflow/efficientnet/b0/feature-vector/1)" brings us to a page with a button that says "Copy URL". That URL is what we can use to harness the power of EfficientNetB0.
#   * Copying the URL should give you something like this: https://tfhub.dev/tensorflow/efficientnet/b0/feature-vector/1
#
# > 🤔 **Question:** *I thought we were doing image classification, why do we choose feature vector and not classification?*
#
# Great observation. This is where the differnet types of transfer learning come into play, as is, feature extraction and fine-tuning.
#
# 1. **"As is" transfer learning** is when you take a pretrained model as it is and apply it to your task without any changes.
#
#   * For example, many computer vision models are pretrained on the ImageNet dataset which contains 1000 different classes of images. This means passing a single image to this model will produce 1000 different prediction probability values (1 for each class).
#
#     * This is helpful if you have 1000 classes of image you'd like to classify and they're all the same as the ImageNet classes, however, it's not helpful if you want to classify only a small subset of classes (such as 10 different kinds of food). Model's with `"/classification"` in their name on TensorFlow Hub provide this kind of functionality.
#
# 2. **Feature extraction transfer learning** is when you take the underlying patterns (also called weights) a pretrained model has learned and adjust its outputs to be more suited to your problem.
#
#   * For example, say the pretrained model you were using had 236 different layers (EfficientNetB0 has 236 layers), but the top layer outputs 1000 classes because it was pretrained on ImageNet. To adjust this to your own problem, you might remove the original activation layer and replace it with your own but with the right number of output classes. The important part here is that **only the top few layers become trainable, the rest remain frozen**.
#
#     * This way all the underlying patterns remain in the rest of the layers and you can utilise them for your own problem. This kind of transfer learning is very helpful when your data is similar to the data a model has been pretrained on.
#
# 3. **Fine-tuning transfer learning** is when you take the underlying patterns (also called weights) of a pretrained model and adjust (fine-tune) them to your own problem.
#
#     * This usually means training **some, many or all** of the layers in the pretrained model. This is useful when you've got a large dataset (e.g. 100+ images per class) where your data is slightly different to the data the original model was trained on.
#
# A common workflow is to "freeze" all of the learned patterns in the bottom layers of a pretrained model so they're untrainable. And then train the top 2-3 layers of so the pretrained model can adjust its outputs to your custom data (**feature extraction**).
#
# After you've trained the top 2-3 layers, you can then gradually "unfreeze" more and more layers and run the training process on your own data to further **fine-tune** the pretrained model.
#
# > 🤔 **Question:** *Why train only the top 2-3 layers in feature extraction?*
#
# The lower a layer is in a computer vision model as in, the closer it is to the input layer, the larger the features it learn. For example, a bottom layer in a computer vision model to identify images of cats or dogs might learn the outline of legs, where as, layers closer to the output might learn the shape of teeth. Often, you'll want the larger features (learned patterns are also called features) to remain, since these are similar for both animals, where as, the differences remain in the more fine-grained features.
#
# ![](https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/images/04-different-kinds-of-transfer-learning.png)
# *The different kinds of transfer learning. An original model, a feature extraction model (only top 2-3 layers change) and a fine-tuning model (many or all of original model get changed).*
#
# Okay, enough talk, let's see this in action. Once we do, we'll explain what's happening.
#
# First we'll import TensorFlow and TensorFlow Hub.

# %%
import tensorflow as tf
import tensorflow_hub as hub

print("TensorFlow version:", tf.__version__)
print("TensorFlow Hub version:", hub.__version__)
# Out:
# TensorFlow version: 2.17.0
# TensorFlow Hub version: 0.16.1

# %% [markdown]
# Now we'll get the feature vector URLs of two common computer vision architectures, [EfficientNetB0 (2019)](https://tfhub.dev/tensorflow/efficientnet/b0/feature-vector/1) and [ResNetV250 (2016)](https://tfhub.dev/google/imagenet/resnet_v2_50/feature_vector/4) from TensorFlow Hub using the steps above.
#
# We're getting both of these because we're going to compare them to see which performs better on our data.
#
# > 🔑 **Note:** Comparing different model architecture performance on the same data is a very common practice. The simple reason is because you want to know which model performs best for your problem.
#
# > **Update:** As of 14 August 2021, [EfficientNet V2 pretrained models are available on TensorFlow Hub](https://tfhub.dev/google/collections/efficientnet_v2/1). The original code in this notebook uses EfficientNet V1, it has been left unchanged. In [my experiments with this dataset](https://github.com/mrdbourke/tensorflow-deep-learning/discussions/166), V1 outperforms V2. Best to experiment with your own data and see what suits you.

# %%
# Resnet 50 V2 feature vector
resnet_url = "https://tfhub.dev/google/imagenet/resnet_v2_50/feature_vector/4"

# Original: EfficientNetB0 feature vector (version 1)
# efficientnet_url = "https://tfhub.dev/tensorflow/efficientnet/b0/feature-vector/1"

# New: EfficientNetB0 feature vector (version 2)
efficientnet_url = "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet1k_b0/feature_vector/2"

# %% [markdown]
# These URLs link to a saved pretrained model on TensorFlow Hub.
#
# When we use them in our model, the model will automatically be downloaded for us to use.
#
# To do this, we can use the [`KerasLayer()`](https://www.tensorflow.org/hub/api_docs/python/hub/KerasLayer) model inside the TensorFlow hub library.
#
# Since we're going to be comparing two models, to save ourselves code, we'll create a function `create_model()`. This function will take a model's TensorFlow Hub URL, instatiate a Keras Sequential model with the appropriate number of output layers and return the model.

# %%
import tf_keras as keras

def create_model(model_url, num_classes=10):
    """Takes a TensorFlow Hub URL and creates a Keras Sequential model with it.
    
    Args:
      model_url (str): A TensorFlow Hub feature extraction URL.
      num_classes (int): Number of output neurons in output layer,
        should be equal to number of target classes, default 10.

    Returns:
      An uncompiled Keras Sequential model with model_url as feature
      extractor layer and Dense output layer with num_classes outputs.
    """
    
    # Download the pretrained model and save it as a Keras layer
    feature_extractor_layer = hub.KerasLayer(
        model_url,
        trainable=False, # freeze the underlying patterns
        name='feature_extraction_layer',
        input_shape=IMAGE_SHAPE+(3,) # define the input image shape
    )
    
    # Create our own model
    model = keras.Sequential([
        feature_extractor_layer, # use the feature extraction layer as the base
        keras.layers.Dense(num_classes, activation='softmax', name='output_layer') # create our own output layer      
    ])

    return model

# %% [markdown]
# Great! Now we've got a function for creating a model, we'll use it to first create a model using the ResNetV250 architecture as our feature extraction layer.
#
# Once the model is instantiated, we'll compile it using `categorical_crossentropy` as our loss function, the Adam optimizer and accuracy as our metric.

# %%
# Create model
resnet_model = create_model(resnet_url, num_classes=train_data_10_percent.num_classes)

# Compile
resnet_model.compile(
    loss=keras.losses.CategoricalCrossentropy(), # Our model wants to reduce this (how wrong its guesses are)
    optimizer=keras.optimizers.Adam(), # A friend telling our model how to improve its guesses
    metrics=["accuracy"] # We'd like this to go up
)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1736039144.377519    2148 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:65:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1736039149.147929    2148 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:65:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1736039149.147981    2148 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:65:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1736039149.159370    2148 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:65:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1736039149.159419    2148 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:65:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1736039149.159434    2148 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:65:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1736039149.943509    2148 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:65:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1736039149.943577    2148 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:65:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-05 09:05:49.943591: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1736039149.943639    2148 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:65:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-01-05 09:05:49.953502: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5520 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Laptop GPU, pci bus id: 0000:65:00.0, compute capability: 8.9

# %%
resnet_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  feature_extraction_layer (  (None, 2048)              23564800
#  KerasLayer)
#
#  output_layer (Dense)        (None, 10)                20490
#
# =================================================================
# Total params: 23585290 (89.97 MB)
# Trainable params: 20490 (80.04 KB)
# Non-trainable params: 23564800 (89.89 MB)
# _________________________________________________________________

# %% [markdown]
# ![](https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/images/04-resnet-feature-extractor.png)
# *What our current model looks like. A ResNet50V2 backbone with a custom dense layer on top (10 classes instead of 1000 ImageNet classes). **Note:** The Image shows ResNet34 instead of ResNet50. **Image source:** https://arxiv.org/abs/1512.03385.*
#
# Beautiful. Time to fit the model.
#
# We've got the training data ready in `train_data_10_percent` as well as the test data saved as `test_data`.
#
# But before we call the fit function, there's one more thing we're going to add, a callback. More specifically, a TensorBoard callback so we can track the performance of our model on TensorBoard.
#
# We can add a callback to our model by using the `callbacks` parameter in the fit function.
#
# In our case, we'll pass the `callbacks` parameter the `create_tensorboard_callback()` we created earlier with some specific inputs so we know what experiments we're running.
#
# Let's keep this experiment short and train for 5 epochs.

# %%
# Fit the model
resnet_history = resnet_model.fit(
    train_data_10_percent,
    epochs=5,
    steps_per_epoch=len(train_data_10_percent),
    validation_data=test_data,
    validation_steps=len(test_data),
    # Add TensorBoard callback to model (callbacks parameter takes a list)
    callbacks=[create_tensorboard_callback(
        dir_name="tensorflow_hub",  # save experiment logs here
        experiment_name="resnet50V2"  # name of log files
    )]
)
# Out:
# Saving TensorBoard log files to: tensorflow_hub/resnet50V2/20250105-090551
# Epoch 1/5
# 2025-01-05 09:05:57.608856: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# W0000 00:00:1736039160.659456    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039160.808879    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039160.844167    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039160.950674    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039160.963523    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039161.287049    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039161.308648    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039161.352353    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039161.394995    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039161.420604    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039161.466619    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039161.609495    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039161.661804    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039161.820070    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039162.987523    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039162.989614    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.026203    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.028118    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.030048    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.065010    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.067025    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.094143    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.096261    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.127767    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.164546    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.205584    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.245600    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.247580    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.287146    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.323830    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.325959    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.328619    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.331436    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.333591    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.336940    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.339201    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.533045    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.539079    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.542986    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.548420    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.552643    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.560448    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.569437    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.578887    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.589809    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039163.907344    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.112489    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.206949    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.208252    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.209527    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.210791    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.212069    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.213422    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.214807    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.216151    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.217573    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.219173    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.220532    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.221870    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.223230    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.224697    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.226177    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.227488    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.228932    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.230465    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.231808    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.233499    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.234940    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.236504    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.238680    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.240257    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.241862    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.243676    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.245461    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.247373    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.295081    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.296864    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.298513    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.300105    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.301718    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.303329    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.304985    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.306651    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.308287    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.309871    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.311457    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.313014    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.314784    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.316506    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.318367    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.320322    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.322583    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.324212    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.325977    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.327779    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.329547    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.331375    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.333145    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.335302    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.337671    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.340332    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.343224    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.345304    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.349487    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.353726    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.363995    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.413658    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.417580    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.418553    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.419509    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.420449    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.421397    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.422390    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.423383    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.424444    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.425391    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.426373    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.427317    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.428279    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.429234    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.430212    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.431218    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.432342    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.433310    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.434262    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.435264    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.436286    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.437381    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.438344    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.439597    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.440620    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.442501    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.443766    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.445051    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.476449    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.477904    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.479062    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.480237    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.481384    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.482589    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.483718    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.484907    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.486098    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.487402    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.488620    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.490059    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.491298    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.492486    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.493704    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.495047    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.496285    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.497609    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.498896    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.500142    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.501481    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.502795    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.504106    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.505505    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.507139    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.508496    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.525945    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.527815    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.529514    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.532298    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.535030    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.545446    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.547894    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.548852    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.549753    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.550686    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.551585    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.552502    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.553407    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.554385    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.555318    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.556265    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.557245    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.558160    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.559083    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.560053    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.560984    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.561964    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.562855    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.564022    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.564929    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.565905    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.566976    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.568021    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.569064    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.570196    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.571400    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.572259    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.573225    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.583817    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.585162    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.586414    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.587604    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.588796    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.590001    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.591243    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.592435    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.593643    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.594817    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.596016    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.597316    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.598682    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.599922    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.601200    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.602555    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.603888    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.605227    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.606559    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.607911    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.609298    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.610681    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.611944    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.613713    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.615444    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.617285    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.618855    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.620541    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.623276    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.625868    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039164.629875    5526 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1736039165.174738    5528 service.cc:146] XLA service 0x7f8f69229070 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1736039165.174802    5528 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Laptop GPU, Compute Capability 8.9
# 2025-01-05 09:06:05.420769: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1736039165.892099    5528 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 23/24 [===========================>..] - ETA: 0s - loss: 1.9793 - accuracy: 0.3478
# W0000 00:00:1736039177.809655    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.812457    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.815334    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.818496    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.821625    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.826308    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.830070    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.836242    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.842610    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.847904    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.855563    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.863883    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.880086    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.894643    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.913615    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.916299    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.918477    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.920638    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.922870    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.925112    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.927553    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.929756    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.932316    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.935030    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.937778    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.940171    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.942604    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.944876    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.947592    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.950534    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.952922    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.955726    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.958679    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.961103    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.964772    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.966823    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.968595    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.971240    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.973399    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.975829    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.978949    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.982379    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.985794    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.989752    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039177.993438    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.051200    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.053130    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.054657    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.056097    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.057602    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.059074    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.060561    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.062143    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.063580    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.065125    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.066621    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.068080    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.069500    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.070958    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.072486    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.074078    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.075497    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.077038    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.078560    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.080075    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.081817    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.083401    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.085016    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.087068    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.088670    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.090263    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.091938    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.093673    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.095413    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.123914    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.125940    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.127513    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.129075    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.130654    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.132299    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.133981    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.135691    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.137404    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.139048    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.140623    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.142406    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.144158    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.145877    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.147467    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.149224    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.150813    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.152536    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.154353    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.156417    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.158281    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.160023    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.161823    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.163859    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.165967    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.168241    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.170724    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.174066    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.176427    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.178646    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.180820    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.217492    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.218522    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.219430    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.220325    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.221196    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.222034    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.222908    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.223705    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.224509    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.225329    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.226150    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.227064    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.227963    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.228828    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.229889    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.230723    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.231630    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.232519    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.233406    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.234204    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.235094    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.236121    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.237054    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.237976    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.238951    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.239904    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.240853    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.242595    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 24/24 [==============================] - ETA: 0s - loss: 1.9671 - accuracy: 0.3493
# W0000 00:00:1736039178.275350    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.276668    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.277740    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.278798    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.280009    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.281103    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.282289    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.283322    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.284456    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.285428    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.286411    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.287477    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.288642    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.289832    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.290924    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.291992    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.292989    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.294072    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.295184    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.296442    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.297711    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.298825    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.299868    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.301171    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.302483    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.303720    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.305497    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.306815    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.308636    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.310526    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.323571    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.324566    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039178.325450    5527 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# ...
# W0000 00:00:1736039214.495995    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.497456    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.498905    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.500564    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.502283    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.503966    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.505464    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.507629    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.509833    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.530249    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.531819    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.532963    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.534240    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.535499    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.536650    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.537797    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.538970    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.540148    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.541341    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.542626    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.543981    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.545270    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.546546    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.547854    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.549161    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.550399    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.551744    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.553057    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.554452    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.555849    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.557281    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.558524    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.559804    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.560844    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.561944    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.562903    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.563911    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.565718    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.575955    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.577035    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.577898    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.578811    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.579678    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.580627    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.581571    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.582486    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.583439    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.584335    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.585253    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.586190    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.587230    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.588268    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.589206    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.590137    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.591059    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.592040    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.592995    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.594047    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.595023    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.596097    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.597116    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.598189    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.599274    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.600493    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.601779    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.602989    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.604126    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.605303    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.607090    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.617503    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.618440    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.619259    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.620077    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.620915    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.621720    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.622611    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.623490    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.624300    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.625169    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.626036    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.626921    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.627780    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.628614    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.629470    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.630338    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.631177    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.632140    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.633242    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.634137    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.635071    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.635965    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.637070    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.638049    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.638946    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.639866    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.640979    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.642054    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.652237    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.653486    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.654575    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.655557    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.656531    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.657490    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.658478    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.659549    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.660557    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.661596    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.662650    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.663734    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.664773    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.665840    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.666926    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.668032    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.669362    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.670407    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.671416    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.672640    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.673892    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.675110    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.676232    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.677499    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.678715    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 24/24 [==============================] - 60s 2s/step - loss: 1.9671 - accuracy: 0.3493 - val_loss: 1.1944 - val_accuracy: 0.6212
# Epoch 2/5
# W0000 00:00:1736039214.679985    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.681629    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.682935    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.684357    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736039214.685810    5529 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 24/24 [==============================] - 18s 796ms/step - loss: 0.9434 - accuracy: 0.7267 - val_loss: 0.8711 - val_accuracy: 0.7152
# Epoch 3/5
# 24/24 [==============================] - 18s 767ms/step - loss: 0.6631 - accuracy: 0.8213 - val_loss: 0.7684 - val_accuracy: 0.7504
# Epoch 4/5
# 24/24 [==============================] - 17s 746ms/step - loss: 0.4971 - accuracy: 0.8627 - val_loss: 0.6896 - val_accuracy: 0.7776
# Epoch 5/5
# 24/24 [==============================] - 15s 664ms/step - loss: 0.3981 - accuracy: 0.9067 - val_loss: 0.6909 - val_accuracy: 0.7692

# %% [markdown]
# Wow!
#
# It seems that after only 5 epochs, the ResNetV250 feature extraction model was able to blow any of the architectures we made out of the water, achieving around 90% accuracy on the training set and nearly 80% accuracy on the test set...**with only 10 percent of the training images!**
#
# That goes to show the power of transfer learning. And it's one of the main reasons whenever you're trying to model your own datasets, you should look into what pretrained models already exist.
#
# Let's check out our model's training curves using our `plot_loss_curves` function.

# %%
# If you wanted to, you could really turn this into a helper function to load in with a helper.py script...
import matplotlib.pyplot as plt

# Plot the validation and training data separately
def plot_loss_curves(history):
    """
    Returns separate loss curves for training and validation metrics.
    """ 
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']

    epochs = range(len(history.history['loss']))

    # Plot loss
    plt.plot(epochs, loss, label='training_loss')
    plt.plot(epochs, val_loss, label='val_loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.legend()

    # Plot accuracy
    plt.figure()
    plt.plot(epochs, accuracy, label='training_accuracy')
    plt.plot(epochs, val_accuracy, label='val_accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.legend();

# %%
plot_loss_curves(resnet_history)

# %%
# Resnet summary 
resnet_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  feature_extraction_layer (  (None, 2048)              23564800
#  KerasLayer)
#
#  output_layer (Dense)        (None, 10)                20490
#
# =================================================================
# Total params: 23585290 (89.97 MB)
# Trainable params: 20490 (80.04 KB)
# Non-trainable params: 23564800 (89.89 MB)
# _________________________________________________________________
